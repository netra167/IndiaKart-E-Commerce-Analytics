# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-32b3b9a1-3d41-4670-b6fe-50855a2adecd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-32b3b9a1-3d41-4670-b6fe-50855a2adecd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Load all files

# %%
import pandas as pd

customers = pd.read_csv("customers DA.csv")
orders = pd.read_csv("orders DA.csv")
order_items = pd.read_csv("order_items DA.csv")
payments = pd.read_csv("payments DA.csv")
products = pd.read_csv("products DA.csv")
returns = pd.read_csv("returns DA.csv")
suppliers = pd.read_csv("suppliers DA.csv")
inventory = pd.read_csv("inventory DA.csv")

# %%
print("Customers:", customers.shape)
print("Orders:", orders.shape)
print("Order Items:", order_items.shape)
print("Payments:", payments.shape)
print("Products:", products.shape)
print("Returns:", returns.shape)
print("Suppliers:", suppliers.shape)
print("Inventory:", inventory.shape)
# Out:
# Customers: (10000, 17)
# Orders: (50000, 19)
# Order Items: (100000, 11)
# Payments: (50000, 13)
# Products: (1000, 17)
# Returns: (10000, 10)
# Suppliers: (200, 14)
# Inventory: (1000, 11)

# %% [markdown]
# import library

# %%
import pandas as pd

# %%
import os

os.listdir()
# Out:
# ['.config',
#  'customers DA.csv',
#  'products DA.csv',
#  'payments DA.csv',
#  'order_items DA.csv',
#  'orders DA.csv',
#  'returns DA.csv',
#  'suppliers DA.csv',
#  'inventory DA.csv',
#  'sample_data']

# %% [markdown]
# Customers Data cleaning

# %%
customers.head()
# Out:
#   customer_id first_name   last_name                            email  \
# 0   CUST00001      Kunal       Gupta         kunal.gupta223@gmail.com
# 1   CUST00002      Aryan       Gupta          aryan.gupta336@yahoo.in
# 2   CUST00003      Akash  Chatterjee  akash.chatterjee584@hotmail.com
# 3   CUST00004    Madhuri       Walia       madhuri.walia878@gmail.com
# 4   CUST00005     Vishal         Das           vishal.das342@yahoo.in
#
#         phone         city           state  pincode  gender  age  segment  \
# 0  9117912889     Guwahati           Assam   314040    Male   54      New
# 1  9271550550  Navi Mumbai     Maharashtra   799535  Female   26   Budget
# 2  9559676548        Surat         Gujarat   738196  Female   24  Regular
# 3  9673322422      Gwalior  Madhya Pradesh   238106  Female   23  Regular
# 4  9920855521      Dhanbad       Jharkhand   783291  Female   59  Regular
#
#   registration_date last_login_date  is_verified  is_active  total_orders  \
# ...

# %%
customers.shape
# Out:
# (10000, 17)

# %%
customers.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'email', 'phone', 'city',
#        'state', 'pincode', 'gender', 'age', 'segment', 'registration_date',
#        'last_login_date', 'is_verified', 'is_active', 'total_orders',
#        'total_spent'],
#       dtype='object')

# %%
customers.dtypes
# Out:
# customer_id           object
# first_name            object
# last_name             object
# email                 object
# phone                  int64
# city                  object
# state                 object
# pincode                int64
# gender                object
# age                    int64
# segment               object
# registration_date     object
# last_login_date       object
# is_verified            int64
# is_active              int64
# total_orders           int64
# total_spent          float64
# dtype: object

# %%
customers.isnull().sum()
# Out:
# customer_id          0
# first_name           0
# last_name            0
# email                0
# phone                0
# city                 0
# state                0
# pincode              0
# gender               0
# age                  0
# segment              0
# registration_date    0
# last_login_date      0
# is_verified          0
# is_active            0
# total_orders         0
# total_spent          0
# dtype: int64

# %%
customers.isnull().mean().mul(100).round(2)
# Out:
# customer_id          0.0
# first_name           0.0
# last_name            0.0
# email                0.0
# phone                0.0
# city                 0.0
# state                0.0
# pincode              0.0
# gender               0.0
# age                  0.0
# segment              0.0
# registration_date    0.0
# last_login_date      0.0
# is_verified          0.0
# is_active            0.0
# total_orders         0.0
# total_spent          0.0
# dtype: float64

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers["customer_id"].duplicated().sum()
# Out:
# np.int64(0)

# %%
(customers["total_orders"] == 0).sum()
# Out:
# np.int64(457)

# %%
customers["is_verified"].value_counts()
# Out:
# is_verified
# 1    8418
# 0    1582
# Name: count, dtype: int64

# %%
customers["is_active"].value_counts()
# Out:
# is_active
# 1    8755
# 0    1245
# Name: count, dtype: int64

# %%
customers["age"].describe()
# Out:
# count    10000.00000
# mean        41.67630
# std         13.83438
# min         18.00000
# 25%         30.00000
# 50%         42.00000
# 75%         54.00000
# max         65.00000
# Name: age, dtype: float64

# %%
customers["total_orders"].describe()
# Out:
# count    10000.000000
# mean         5.000000
# std          3.069942
# min          0.000000
# 25%          3.000000
# 50%          5.000000
# 75%          7.000000
# max         19.000000
# Name: total_orders, dtype: float64

# %%
customers["total_spent"].describe()
# Out:
# count    1.000000e+04
# mean     3.147386e+05
# std      2.903266e+05
# min      0.000000e+00
# 25%      8.842337e+04
# 50%      2.356611e+05
# 75%      4.660584e+05
# max      1.999913e+06
# Name: total_spent, dtype: float64

# %%
customers["gender"].value_counts(dropna=False)
# Out:
# gender
# Male      5168
# Female    4564
# Other      268
# Name: count, dtype: int64

# %%
customers["segment"].value_counts(dropna=False)
# Out:
# segment
# Regular     4026
# Budget      2505
# Premium     1501
# New         1488
# Inactive     480
# Name: count, dtype: int64

# %%
customers["registration_date"].head(10)
# Out:
# 0    30-07-2024
# 1    05-07-2023
# 2    14-05-2022
# 3    21-01-2025
# 4    06-06-2023
# 5    06-04-2022
# 6    10-06-2022
# 7    04-08-2021
# 8    24-11-2022
# 9    20-11-2024
# Name: registration_date, dtype: object

# %% [markdown]
# Convert registration_date to datetime

# %%
customers["registration_date"] = pd.to_datetime(
    customers["registration_date"],
    format="%d-%m-%Y",
    errors="coerce"
)

# %%
customers["registration_date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
customers["registration_date"].isnull().sum()
# Out:
# np.int64(0)

# %%
customers["last_login_date"].head(10)
# Out:
# 0    10-04-2025
# 1    03-05-2024
# 2    31-10-2023
# 3    22-05-2025
# 4    29-03-2024
# 5    21-10-2022
# 6    06-04-2023
# 7    29-03-2023
# 8    18-05-2025
# 9    21-01-2025
# Name: last_login_date, dtype: object

# %% [markdown]
# Convert last_login_date to datetime

# %%
customers["last_login_date"] = pd.to_datetime(
    customers["last_login_date"],
    format="%d-%m-%Y",
    errors="coerce"
)

# %%
customers["last_login_date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
customers["last_login_date"].isnull().sum()
# Out:
# np.int64(0)

# %%
customers["phone"].head(10)
# Out:
# 0    9117912889
# 1    9271550550
# 2    9559676548
# 3    9673322422
# 4    9920855521
# 5    9809180864
# 6    9718044438
# 7    9143287667
# 8    9238159208
# 9    9938859478
# Name: phone, dtype: int64

# %%
customers["phone"].astype(str).str.len().value_counts()
# Out:
# phone
# 10    10000
# Name: count, dtype: int64

# %%
customers["pincode"].astype(str).str.len().value_counts()
# Out:
# pincode
# 6    10000
# Name: count, dtype: int64

# %%
email_pattern = r"^[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}$"

customers["email"].str.match(email_pattern).value_counts()
# Out:
# email
# True    10000
# Name: count, dtype: int64

# %% [markdown]
# Validate total_spent

# %%
customers["total_spent"].lt(0).sum()
# Out:
# np.int64(0)

# %%
customers["total_spent"].nlargest(10)
# Out:
# 3450    1999913.04
# 5551    1997346.16
# 6800    1983951.26
# 7345    1928170.04
# 5534    1918090.04
# 26      1893655.96
# 7424    1892535.76
# 7573    1863718.85
# 1061    1858684.83
# 4362    1857479.68
# Name: total_spent, dtype: float64

# %%
customers[
    (customers["total_orders"] == 0) &
    (customers["total_spent"] > 0)
].shape
# Out:
# (0, 17)

# %%
customers[
    (customers["total_orders"] > 0) &
    (customers["total_spent"] == 0)
].shape
# Out:
# (0, 17)

# %%
customers.isnull().sum()
# Out:
# customer_id          0
# first_name           0
# last_name            0
# email                0
# phone                0
# city                 0
# state                0
# pincode              0
# gender               0
# age                  0
# segment              0
# registration_date    0
# last_login_date      0
# is_verified          0
# is_active            0
# total_orders         0
# total_spent          0
# dtype: int64

# %%
customers.to_csv("customers_cleaned.csv", index=False)

# %%
import os

os.path.exists("customers_cleaned.csv")
# Out:
# True
